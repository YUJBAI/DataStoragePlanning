# %%
import os
import pandas as pd
import re
import matplotlib.pyplot as plt

# %%
# Get current directory and change to the data stored path
print("Current directory:",os.getcwd())

path = "/stornext/HPCScratch/rcp_sf_data/starfish_data/summary_by_day"
os.chdir(path)

# List all files 
all_files = os.listdir(path)
# Out:
# Current directory: /stornext/Home/data/allstaff/z/zhou.yo

# %%
# Concat all files into one file
file_list = []
for filename in all_files:
    df = pd.read_csv(filename)
    df['filename'] = filename
    file_list.append(df)
data = pd.concat(file_list, axis=0, ignore_index=True)

# %%
data.dtypes
# Out:
# volume name                              object
# capacity (GiB)                          float64
# used physical (GiB)                     float64
# used logical (GiB)                      float64
# free (GiB)                              float64
# used %                                  float64
# regular files                            object
# symbolic links                           object
# max file size (GiB)                     float64
# median file size (bytes)                 object
# average file size (bytes)                object
# directories                              object
# directories with subdirectories only     object
# empty directories                        object
# max dir size (GiB)                      float64
# run_time                                 object
# filename                                 object
# dtype: object

# %% [markdown]
# ## Clean Volume name

# %%
pattern = "[A-Z]\w*"
cleaned_name = [re.search(pattern,volume_name).group() for volume_name in data["volume name"]]
data["volume name"] = cleaned_name

# %%
data.head()
# Out:
#   volume name  capacity (GiB)  used physical (GiB)  used logical (GiB)  \
# 0      Bioinf       476836.88            452991.40          2045229.43
# 1    Projects       366941.01            159508.05           264816.49
# 2     General       500562.34            329524.32          1099954.85
# 3    Genomics        62570.29             41686.21            88837.25
# 4        Home       238418.44             93698.70           507026.26
#
#    free (GiB)  used % regular files symbolic links  max file size (GiB)  \
# 0    23845.47    95.0      65081232         696836              7687.31
# 1   207432.96    43.5      43451260         153389               635.62
# 2   171038.02    65.8     237069959        2182642               954.28
# 3    20884.08    66.6       5306768          93224               188.85
# 4   144719.74    39.3     117911464        1080222               623.61
#
#   median file size (bytes) average file size (bytes) directories  \
# 0                     5598                  33780535     3467941
# 1                    48457                   6543863      445345
# 2                    46818                   4984182     6698668
# 3                    26898                  17974782     1225326
# 4                     6585                   4619693     8589748
#
#   directories with subdirectories only empty directories  max dir size (GiB)  \
# 0                               923935            422101            46895.55
# 1                               177355            124779             7751.23
# 2                              1265674            634557             8453.05
# 3                               318485            278915             3305.27
# 4                              2078735           1101354             3065.48
#
#         run_time        filename
# 0  18/11/20 4:00  2020-11-18.csv
# 1  18/11/20 4:00  2020-11-18.csv
# 2  18/11/20 4:00  2020-11-18.csv
# 3  18/11/20 4:00  2020-11-18.csv
# 4  18/11/20 4:00  2020-11-18.csv

# %% [markdown]
# ## Clean Date Format

# %%
date = [time.split()[0] for time in data["run_time"]]

# %%
date = pd.to_datetime(date,format='%d/%m/%y') 
data["date"] = date

# %%
data.dtypes
# Out:
# volume name                                     object
# capacity (GiB)                                 float64
# used physical (GiB)                            float64
# used logical (GiB)                             float64
# free (GiB)                                     float64
# used %                                         float64
# regular files                                   object
# symbolic links                                  object
# max file size (GiB)                            float64
# median file size (bytes)                        object
# average file size (bytes)                       object
# directories                                     object
# directories with subdirectories only            object
# empty directories                               object
# max dir size (GiB)                             float64
# run_time                                        object
# filename                                        object
# date                                    datetime64[ns]
# dtype: object

# %% [markdown]
# ## Keep the physical and logical columns

# %%
data = data[['date','volume name', 'capacity (GiB)', 'used physical (GiB)',
       'used logical (GiB)', 'free (GiB)', 'used %']]

# %% [markdown]
# ## Missing and Noisy data clean

# %%
data = data.sort_values(["volume name", "date"], ascending = (True, True))
data = data.reset_index(drop = True)

# %%
data
# Out:
#            date volume name  capacity (GiB)  used physical (GiB)  \
# 0    2020-11-03       Admin        32767.98              1080.94
# 1    2020-11-04       Admin        32767.98              1080.94
# 2    2020-11-05       Admin        32767.98              1080.94
# 3    2020-11-06       Admin        32767.98              1080.94
# 4    2020-11-07       Admin        32767.98              1080.94
# ...         ...         ...             ...                  ...
# 2816 2021-06-06      System        32767.98              9943.52
# 2817 2021-06-07      System        32767.98             10135.55
# 2818 2021-06-08      System        32767.98             10327.59
# 2819 2021-06-09      System        32767.98             10567.96
# 2820 2021-06-10      System        32767.98             10759.99
#
#       used logical (GiB)  free (GiB)  used %
# 0                 996.14    31687.05     3.3
# 1                 996.14    31687.05     3.3
# 2                 996.14    31687.04     3.3
# 3                 996.14    31687.04     3.3
# 4                 996.14    31687.04     3.3
# ...                  ...         ...     ...
# 2816            87830.62    22824.47    30.3
# 2817            87990.45    22632.43    30.9
# 2818            88179.21    22440.39    31.5
# 2819            88410.56    22200.02    32.3
# 2820            88600.87    22008.00    32.8
#
# [2821 rows x 7 columns]

# %%
# There are some noisy total capacity values with number  9.99
data[data["capacity (GiB)"] < 100]
# Out:
#            date volume name  capacity (GiB)  used physical (GiB)  \
# 42   2020-12-15       Admin            9.99              1081.07
# 162  2021-04-14       Admin            9.99              1059.14
# 196  2021-05-18       Admin            9.99              1059.28
# 198  2021-05-23       Admin            9.99              1059.29
# 200  2021-05-25       Admin            9.99              1059.29
# ...         ...         ...             ...                  ...
# 2646 2020-12-15      System            9.99              4947.81
# 2766 2021-04-14      System            9.99              5028.24
# 2800 2021-05-18      System            9.99              6833.58
# 2802 2021-05-23      System            9.99              7057.54
# 2804 2021-05-25      System            9.99              7634.17
#
#       used logical (GiB)  free (GiB)  used %
# 42                996.27         0.0   100.0
# 162               974.60         0.0   100.0
# 196               974.74         0.0   100.0
# 198               974.74         0.0   100.0
# 200               974.74         0.0   100.0
# ...                  ...         ...     ...
# 2646            83121.83         0.0   100.0
# 2766            83184.73         0.0   100.0
# 2800            85056.29         0.0   100.0
# 2802            85214.31         0.0   100.0
# 2804            85747.39         0.0   100.0
#
# [65 rows x 7 columns]

# %%
# Use the number of the day before 5 days from the missing date to impute the invalid capacity value
# e.g. use 2020-12-10 to impute 2020-12-15

missing_index = data[data["capacity (GiB)"] < 100].index
correct_index = missing_index-5

# %%
# The missing datas are: 
set(data["date"][missing_index])
# Out:
# {Timestamp('2020-12-15 00:00:00'),
#  Timestamp('2021-04-14 00:00:00'),
#  Timestamp('2021-05-18 00:00:00'),
#  Timestamp('2021-05-23 00:00:00'),
#  Timestamp('2021-05-25 00:00:00')}

# %%
data["capacity (GiB)"][missing_index] = data.loc[correct_index]["capacity (GiB)"]
# Out:
# <ipython-input-22-5dbcf4b0c923>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["capacity (GiB)"][missing_index] = data.loc[correct_index]["capacity (GiB)"]

# %%
# update the used percentage using the cleaned capacity
data["used %"] = round(data["used physical (GiB)"] / data["capacity (GiB)"] * 100,1)

# %% [markdown]
# ## MinMax Scaler

# %%
data['Physical Normalised'] = data.groupby('volume name')['used physical (GiB)'].apply(lambda x: (x-x.min())/(x.max()-x.min()))

# %%
data['Logical Normalised'] = data.groupby('volume name')['used logical (GiB)'].apply(lambda x: (x-x.min())/(x.max()-x.min()))

# %% [markdown]
# ## One Abnormal Data
#
# Haven't figured it out..

# %%
data[data["capacity (GiB)"] < data["used physical (GiB)"]]
# Out:
#           date volume name  capacity (GiB)  used physical (GiB)  \
# 849 2021-05-23        DBkp        98303.96            112634.13
#
#      used logical (GiB)  free (GiB)  used %  Physical Normalised  \
# 849          2101326.37         0.0   114.6                  1.0
#
#      Logical Normalised
# 849            0.571499

# %% [markdown]
# ---

# %% [markdown]
# ## Save the preprocessed data

# %%
data = data.sort_values(["volume name", "date"], ascending = (True, True))
mypath = "/stornext/Home/data/allstaff/z/zhou.yo"
os.chdir(mypath)
data.to_csv("merge_data.csv",index = False)

# %%
data
# Out:
#            date volume name  capacity (GiB)  used physical (GiB)  \
# 0    2020-11-03       Admin        32767.98              1080.94
# 1    2020-11-04       Admin        32767.98              1080.94
# 2    2020-11-05       Admin        32767.98              1080.94
# 3    2020-11-06       Admin        32767.98              1080.94
# 4    2020-11-07       Admin        32767.98              1080.94
# ...         ...         ...             ...                  ...
# 2816 2021-06-06      System        32767.98              9943.52
# 2817 2021-06-07      System        32767.98             10135.55
# 2818 2021-06-08      System        32767.98             10327.59
# 2819 2021-06-09      System        32767.98             10567.96
# 2820 2021-06-10      System        32767.98             10759.99
#
#       used logical (GiB)  free (GiB)  used %  Physical Normalised  \
# 0                 996.14    31687.05     3.3             0.708957
# 1                 996.14    31687.05     3.3             0.708957
# 2                 996.14    31687.04     3.3             0.708957
# 3                 996.14    31687.04     3.3             0.708957
# 4                 996.14    31687.04     3.3             0.708957
# ...                  ...         ...     ...                  ...
# 2816            87830.62    22824.47    30.3             0.859741
# 2817            87990.45    22632.43    30.9             0.892729
# 2818            88179.21    22440.39    31.5             0.925719
# 2819            88410.56    22200.02    32.3             0.967012
# 2820            88600.87    22008.00    32.8             1.000000
#
#       Logical Normalised
# 0               0.709283
# 1               0.709283
# 2               0.709283
# 3               0.709283
# 4               0.709283
# ...                  ...
# 2816            0.863340
# 2817            0.891697
# 2818            0.925188
# 2819            0.966235
# 2820            1.000000
#
# [2821 rows x 9 columns]
